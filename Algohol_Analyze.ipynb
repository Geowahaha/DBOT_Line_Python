# %% [markdown]
# <a href="https://colab.research.google.com/github/Geowahaha/DBOT_Line_Python/blob/master/Algohol_Analyze.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set(style="whitegrid")

# %%
df1 = pd.read_csv("/content/drive/My Drive/BOTNOI Data/Class 1/Homework/student-mat.csv")
df2 = pd.read_csv("/content/drive/My Drive/BOTNOI Data/Class 1/Homework/student-por.csv")

# %%
df = pd.concat([df1,df2],ignore_index=True)

# %%
# school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# sex - student's sex (binary: 'F' - female or 'M' - male)
# age - student's age (numeric: from 15 to 22)
# address - student's home address type (binary: 'U' - urban or 'R' - rural)
# famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# traveltime - home to school travel time (numeric: 1 - 1 hour)
# studytime - weekly study time (numeric: 1 - 10 hours)
# failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# schoolsup - extra educational support (binary: yes or no)
# famsup - family educational support (binary: yes or no)
# paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# activities - extra-curricular activities (binary: yes or no)
# nursery - attended nursery school (binary: yes or no)
# higher - wants to take higher education (binary: yes or no)
# internet - Internet access at home (binary: yes or no)
# romantic - with a romantic relationship (binary: yes or no)
# famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# health - current health status (numeric: from 1 - very bad to 5 - very good)
# absences - number of school absences (numeric: from 0 to 93)
# These grades are related with the course subject, Math or Portuguese:

# G1 - first period grade (numeric: from 0 to 20)
# G2 - second period grade (numeric: from 0 to 20)
# G3 - final grade (numeric: from 0 to 20, output target)

# %%
df["school"] = df["school"].str.replace("GP","Gabriel Pereira")
df["school"] = df["school"].str.replace("MS","Mousinho da Silveira")

# %%
def getgrade1text(data):

  focus = data["G1"]
  if focus >= 0 and focus <= 6:
    focus_text = "Weak"
  elif focus >6 and focus <= 12:
    focus_text = "Medium"
  elif focus >=13 and focus <= 18:
    focus_text = "Good"
  elif focus >= 19 :
    focus_text = "Expert"
  else:
    focus_text = "Error"
  return(focus_text)


def getgrade2text(data):

  focus = data["G2"]
  if focus >= 0 and focus <= 6:
    focus_text = "Weak"
  elif focus >6 and focus <= 12:
    focus_text = "Medium"
  elif focus >=13 and focus <= 18:
    focus_text = "Good"
  elif focus >= 19 :
    focus_text = "Expert"
  else:
    focus_text = "Error"
  return(focus_text)


def getgrade3text(data):

  focus = data["G3"]
  if focus >= 0 and focus <= 6:
    focus_text = "Weak"
  elif focus >6 and focus <= 12:
    focus_text = "Medium"
  elif focus >=13 and focus <= 18:
    focus_text = "Good"
  elif focus >= 19 :
    focus_text = "Expert"
  else:
    focus_text = "Error"
  return(focus_text)

# %%
df["G1_Grade"] = df.apply(getgradetext,axis=1)
df["G2_Grade"] = df.apply(getgradetext,axis=1)
df["G3_Grade"] = df.apply(getgradetext,axis=1)

# %%
df
# Out:
#                     school sex  age address  ...  G3 G1_Grade  G2_Grade  G3_Grade
# 0          Gabriel Pereira   F   18       U  ...   6     Weak      Weak      Weak
# 1          Gabriel Pereira   F   17       U  ...   6     Weak      Weak      Weak
# 2          Gabriel Pereira   F   15       U  ...  10   Medium    Medium    Medium
# 3          Gabriel Pereira   F   15       U  ...  15     Good      Good      Good
# 4          Gabriel Pereira   F   16       U  ...  10     Weak      Weak      Weak
# ...                    ...  ..  ...     ...  ...  ..      ...       ...       ...
# 1039  Mousinho da Silveira   F   19       R  ...  10   Medium    Medium    Medium
# 1040  Mousinho da Silveira   F   18       U  ...  16     Good      Good      Good
# 1041  Mousinho da Silveira   F   18       U  ...   9   Medium    Medium    Medium
# 1042  Mousinho da Silveira   M   17       U  ...  10   Medium    Medium    Medium
# ...

# %%
plt.figure(figsize = (10,10))
df.boxplot(rot=40);

# %%
plt.figure(figsize = (10,10))
plt.scatter(df["G3"],df["absences"]);

# %%
df["age"].value_counts().plot(kind="bar",color="r",alpha=0.7,figsize=[10,5],title="Sort by Age");

# %%
df.corr()
# Out:
#                  age      Medu      Fedu  ...        G1        G2        G3
# age         1.000000 -0.130196 -0.138521  ... -0.124121 -0.119475 -0.125282
# Medu       -0.130196  1.000000  0.642063  ...  0.226101  0.224662  0.201472
# Fedu       -0.138521  0.642063  1.000000  ...  0.195898  0.182634  0.159796
# traveltime  0.049216 -0.238181 -0.196328  ... -0.121053 -0.140163 -0.102627
# studytime  -0.007870  0.090616  0.033458  ...  0.211314  0.183167  0.161629
# failures    0.282364 -0.187769 -0.191390  ... -0.374175 -0.377172 -0.383145
# famrel      0.007162  0.015004  0.013066  ...  0.036947  0.042054  0.054461
# freetime    0.002645  0.001054  0.002142  ... -0.051985 -0.068952 -0.064890
# goout       0.118510  0.025614  0.030075  ... -0.101163 -0.108411 -0.097877
# Dalc        0.133453  0.001515 -0.000165  ... -0.150943 -0.131576 -0.129642
# Walc        0.098291 -0.029331  0.019524  ... -0.142401 -0.128114 -0.115740
# ...

# %%
plt.figure(figsize = (17,15))
sns.heatmap(df.corr(),annot=True);

# %%
#ตั้งสมมติฐาน

# คนที่อาศัยอยู่กับครอบครัวในบ้านเดียวกัน คะแนนจะดี คนที่อยู่หอพักอาจจะได้คะแนนที่ไม่ดี
# Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# G3 - final grade (numeric: from 0 to 20, output target)

# %%
plt.figure(figsize = (10,10))
sns.heatmap(df.groupby(by="Pstatus").mean(),annot=True);

# %%
plt.figure(figsize = (10,10))
sns.heatmap(df.groupby(by="sex").mean(),annot=True);

# %%
plt.figure(figsize = (10,10))
sns.heatmap(df.groupby(by="paid").mean(),annot=True);

# %%
#ทดลองแบ่ง Cluster ดู

# %%
df
# Out:
#                     school sex  age address  ... absences  G1  G2  G3
# 0          Gabriel Pereira   F   18       U  ...        6   5   6   6
# 1          Gabriel Pereira   F   17       U  ...        4   5   5   6
# 2          Gabriel Pereira   F   15       U  ...       10   7   8  10
# 3          Gabriel Pereira   F   15       U  ...        2  15  14  15
# 4          Gabriel Pereira   F   16       U  ...        4   6  10  10
# ...                    ...  ..  ...     ...  ...      ...  ..  ..  ..
# 1039  Mousinho da Silveira   F   19       R  ...        4  10  11  10
# 1040  Mousinho da Silveira   F   18       U  ...        4  15  15  16
# 1041  Mousinho da Silveira   F   18       U  ...        6  11  12   9
# 1042  Mousinho da Silveira   M   17       U  ...        6  10  10  10
# 1043  Mousinho da Silveira   M   18       R  ...        4  10  11  11
#
# [1044 rows x 33 columns]

# %%
prepare_for_clus = df[["G1","G2","G3"]]

# %%
prepare_for_clus
# Out:
#       G1  G2  G3
# 0      5   6   6
# 1      5   5   6
# 2      7   8  10
# 3     15  14  15
# 4      6  10  10
# ...   ..  ..  ..
# 1039  10  11  10
# 1040  15  15  16
# 1041  11  12   9
# 1042  10  10  10
# 1043  10  11  11
#
# [1044 rows x 3 columns]

# %%
from sklearn.cluster import KMeans
clus = KMeans(n_clusters=3, random_state=0).fit_predict(prepare_for_clus)

# %%
prepare_for_clus["clus_Grade"] = clus

# %%
prepare_for_clus[prepare_for_clus["clus_Grade"]==0]
# Out:
#       G1  G2  G3  clus_Grade
# 3     15  14  15           0
# 5     15  15  15           0
# 8     16  18  19           0
# 9     14  15  15           0
# 12    14  14  14           0
# ...   ..  ..  ..         ...
# 1029  16  16  16           0
# 1031  17  18  19           0
# 1033  14  15  16           0
# 1036  14  17  15           0
# 1040  15  15  16           0
#
# [365 rows x 4 columns]

# %%
prepare_for_clus[prepare_for_clus["clus_Grade"]==1]
# Out:
#       G1  G2  G3  clus_Grade
# 0      5   6   6           1
# 1      5   5   6           1
# 7      6   5   6           1
# 18     6   5   5           1
# 35     8   7   6           1
# ...   ..  ..  ..         ...
# 1005   8   0   0           1
# 1021   7   5   0           1
# 1032   7   7   0           1
# 1034   5   8   0           1
# 1035   7   7   0           1
#
# [127 rows x 4 columns]

# %%
prepare_for_clus[prepare_for_clus["clus_Grade"]==2]
# Out:
#       G1  G2  G3  clus_Grade
# 2      7   8  10           2
# 4      6  10  10           2
# 6     12  12  11           2
# 10    10   8   9           2
# 11    10  12  12           2
# ...   ..  ..  ..         ...
# 1038   7   9  10           2
# 1039  10  11  10           2
# 1041  11  12   9           2
# 1042  10  10  10           2
# 1043  10  11  11           2
#
# [552 rows x 4 columns]

# %%
prepare_for_clus["clus_Grade"] = prepare_for_clus["clus_Grade"].replace(0,"High Performance")
prepare_for_clus["clus_Grade"] = prepare_for_clus["clus_Grade"].replace(1,"Bad Performance")
prepare_for_clus["clus_Grade"] = prepare_for_clus["clus_Grade"].replace(2,"Medium Performance")

# %%
datamart = prepare_for_clus[["clus_Grade"]].copy()

# %%
datamart
# Out:
#               clus_Grade
# 0        Bad Performance
# 1        Bad Performance
# 2     Medium Performance
# 3       High Performance
# 4     Medium Performance
# ...                  ...
# 1039  Medium Performance
# 1040    High Performance
# 1041  Medium Performance
# 1042  Medium Performance
# 1043  Medium Performance
#
# [1044 rows x 1 columns]

# %%
prepare_for_clus2 = df[["health","absences"]]

# %%
prepare_for_clus2
# Out:
#       health  absences
# 0          3         6
# 1          3         4
# 2          3        10
# 3          5         2
# 4          5         4
# ...      ...       ...
# 1039       5         4
# 1040       1         4
# 1041       5         6
# 1042       2         6
# 1043       5         4
#
# [1044 rows x 2 columns]

# %%
clus_2 = KMeans(n_clusters=2, random_state=0).fit_predict(prepare_for_clus2)

# %%
prepare_for_clus2["Clus_2"] = clus_2

# %%
prepare_for_clus2[prepare_for_clus2["Clus_2"] == 0]
# Out:
#       health  absences  Clus_2
# 0          3         6       0
# 1          3         4       0
# 3          5         2       0
# 4          5         4       0
# 6          3         0       0
# ...      ...       ...     ...
# 1039       5         4       0
# 1040       1         4       0
# 1041       5         6       0
# 1042       2         6       0
# 1043       5         4       0
#
# [881 rows x 3 columns]

# %%
prepare_for_clus2[prepare_for_clus2["Clus_2"] == 1]
# Out:
#       health  absences  Clus_2
# 2          3        10       1
# 5          5        10       1
# 18         5        16       1
# 25         5        14       1
# 29         5        16       1
# ...      ...       ...     ...
# 932        5        11       1
# 964        3         9       1
# 968        5         9       1
# 969        4        12       1
# 1030       1        10       1
#
# [163 rows x 3 columns]

# %%
prepare_for_clus2[prepare_for_clus2["Clus_2"] == 2]
# Out:
#      health  absences  Clus_2
# 40        3        25       2
# 74        5        54       2
# 103       2        26       2
# 183       1        56       2
# 198       2        24       2
# 205       5        28       2
# 216       1        22       2
# 276       5        75       2
# 277       3        22       2
# 280       5        30       2
# 307       4        38       2
# 313       1        22       2
# 315       3        40       2
# 320       5        23       2
# 545       1        24       2
# 550       5        22       2
# 592       1        32       2
# 607       2        30       2
# 651       1        26       2
# 720       5        22       2

# %%
prepare_for_clus2["Clus_2"]=prepare_for_clus2["Clus_2"].replace(0,"absence_less")
prepare_for_clus2["Clus_2"]=prepare_for_clus2["Clus_2"].replace(1,"absence_mid")
prepare_for_clus2["Clus_2"]=prepare_for_clus2["Clus_2"].replace(2,"absence_high")

# %%
datamart["Absense_type"] = prepare_for_clus2["Clus_2"]

# %%
datamart["sex"] = df["sex"]
datamart["sex"]=datamart["sex"].replace("F","Female")
datamart["sex"]=datamart["sex"].replace("M","Male")

# %%
datamart["family_size"] = df["famsize"]

# %%
datamart["family_size"]=datamart["family_size"].replace("GT3","Large")
datamart["family_size"]=datamart["family_size"].replace("LE3","Small")

# %%
datamart["internet"] = df["internet"]
datamart["internet"] = datamart["internet"].replace("yes","Play_internet")
datamart["internet"] = datamart["internet"].replace("no","Notplay_internet")

# %%
datamart["guardian"] = df["guardian"]

# %%
datamart["paid"] = df["paid"]
datamart["paid"] = datamart["paid"].replace("yes","paid")
datamart["paid"] = datamart["paid"].replace("no","nopaid")

# %%
datamart["family_support"] = df["famsup"]
datamart["family_support"] = datamart["family_support"].replace("yes","support")
datamart["family_support"] = datamart["family_support"].replace("no","notsupport")

# %%
datamart["final_term"] = df["G3"]

# %%
datamart
# Out:
#               clus_Grade  Absense_type  ...    paid     family_support
# 0        Bad Performance  absence_less  ...  nopaid  family_notsupport
# 1        Bad Performance  absence_less  ...  nopaid     family_support
# 2     Medium Performance   absence_mid  ...    paid  family_notsupport
# 3       High Performance  absence_less  ...    paid     family_support
# 4     Medium Performance  absence_less  ...    paid     family_support
# ...                  ...           ...  ...     ...                ...
# 1039  Medium Performance  absence_less  ...  nopaid  family_notsupport
# 1040    High Performance  absence_less  ...  nopaid     family_support
# 1041  Medium Performance  absence_less  ...  nopaid  family_notsupport
# 1042  Medium Performance  absence_less  ...  nopaid  family_notsupport
# 1043  Medium Performance  absence_less  ...  nopaid  family_notsupport
#
# [1044 rows x 8 columns]

# %%
sns.heatmap(pd.crosstab(datamart["sex"],datamart["guardian"],normalize=0),annot=True);
plt.show();
sns.heatmap(pd.crosstab(datamart["sex"],datamart["guardian"],normalize=1),annot=True);
plt.show();

# %%
sns.heatmap(pd.crosstab(datamart["sex"],datamart["clus_Grade"],normalize=0),annot=True);
plt.show();
sns.heatmap(pd.crosstab(datamart["sex"],datamart["clus_Grade"],normalize=1),annot=True);
plt.show();

# %%
sns.heatmap(pd.crosstab(datamart["family_size"],datamart["clus_Grade"],normalize=0),annot=True);
plt.show();
sns.heatmap(pd.crosstab(datamart["family_size"],datamart["clus_Grade"],normalize=1),annot=True);
plt.show();

# %%
sns.heatmap(pd.crosstab(datamart["family_support"],datamart["clus_Grade"],normalize=0),annot=True);
plt.show();
sns.heatmap(pd.crosstab(datamart["family_support"],datamart["clus_Grade"],normalize=1),annot=True);
plt.show();

# %%
sns.heatmap(pd.crosstab(datamart["family_support"],datamart["clus_Grade"],normalize=0),annot=True);
plt.show();
sns.heatmap(pd.crosstab(datamart["family_support"],datamart["clus_Grade"],normalize=1),annot=True);
plt.show();
